# %%
import pandas as pd

df = pd.DataFrame({
    "ID":           [1, 2, 3, 4, 4, 5, 6],
    "Nombre":       ["Ana", "Luis", "Eva", "Carlos", "Carlos", None, "Marta"],
    "Departamento": ["IT", "ventas", "IT", "RRHH", "RRHH", "Ventas", "IT "],  # inconsistencias
    "Salario":      [28000, None, 35000, 61000, 61000, 48000, 24000],
    "Edad":         [23, 31, None, 45, 45, 38, 22],
})
print(df)
# Out:
#    ID  Nombre Departamento  Salario  Edad
# 0   1     Ana           IT  28000.0  23.0
# 1   2    Luis       ventas      NaN  31.0
# 2   3     Eva           IT  35000.0   NaN
# 3   4  Carlos         RRHH  61000.0  45.0
# 4   4  Carlos         RRHH  61000.0  45.0
# 5   5     NaN       Ventas  48000.0  38.0
# 6   6   Marta          IT   24000.0  22.0

# %% [markdown]
# # Limpieza de datos
#
# En proyecto reales, rara vez, los datos llegan de forma correcta o perfectas condiciones. Esta es una de las fases más importantes del trabajo, detectar y tratar los datos inconsistentes, valores nulos, duplicados, errores, etc

# %%
## Valores nulos : isnull, dropna, fillna.

# %%
# Detectar nulos
print('Mapa de nulos')
print(df.isnull())

# quiero los nulos pero por columna
print(df.isnull().sum())
# Out:
# Mapa de nulos
#       ID  Nombre  Departamento  Salario   Edad
# 0  False   False         False    False  False
# 1  False   False         False     True  False
# 2  False   False         False    False   True
# 3  False   False         False    False  False
# 4  False   False         False    False  False
# 5  False    True         False    False  False
# 6  False   False         False    False  False
# ID              0
# Nombre          1
# Departamento    0
# Salario         1
# Edad            1
# dtype: int64

# %%
df_sin_nulo = df.dropna()
print(df_sin_nulo)
# Out:
#    ID  Nombre Departamento  Salario  Edad
# 0   1     Ana           IT  28000.0  23.0
# 3   4  Carlos         RRHH  61000.0  45.0
# 4   4  Carlos         RRHH  61000.0  45.0
# 6   6   Marta          IT   24000.0  22.0

# %%
#eliminar solo algunas columnas especificas
df_sin_nulo2 = df.dropna(subset=['Salario','Edad'])
print(df_sin_nulo2)
# Out:
#    ID  Nombre Departamento  Salario  Edad
# 0   1     Ana           IT  28000.0  23.0
# 3   4  Carlos         RRHH  61000.0  45.0
# 4   4  Carlos         RRHH  61000.0  45.0
# 5   5     NaN       Ventas  48000.0  38.0
# 6   6   Marta          IT   24000.0  22.0

# %%
## fillna: rellenar nulos con un valor concreto 
df_relleno = df.copy()

# Valor fijo
df_relleno['Nombre'] = df_relleno['Nombre'].fillna('Desconocido')


print(df_relleno)
# Out:
#    ID       Nombre Departamento  Salario  Edad
# 0   1          Ana           IT  28000.0  23.0
# 1   2         Luis       ventas      NaN  31.0
# 2   3          Eva           IT  35000.0   NaN
# 3   4       Carlos         RRHH  61000.0  45.0
# 4   4       Carlos         RRHH  61000.0  45.0
# 5   5  Desconocido       Ventas  48000.0  38.0
# 6   6        Marta          IT   24000.0  22.0

# %%
# Valor fijo
df_relleno['Nombre'] = df_relleno['Nombre'].fillna('Desconocido')


mediana_salario = df_relleno['Salario'].median()
df_relleno['Salario'] = df_relleno['Salario'].fillna(mediana_salario)


media_edad = df.relleno['Edad'].fillna(media_edad)
df_relleno['Edad'] = df_relleno

print(df_relleno)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 9
#       5 mediana_salario = df_relleno['Salario'].median()
#       6 df_relleno['Salario'] = df_relleno['Salario'].fillna(mediana_salario)
#       7
#       8
# ----> 9 media_edad = df.relleno['Edad'].fillna(media_edad)
#      10 df_relleno['Edad'] = df_relleno
#      11
#      12 print(df_relleno)
#
# File c:\big_data\python\clases_python_bigdata\7_pandas_numpy\pandas\.venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'relleno'
