# %%
import pandas as pd

df = pd.DataFrame({
    "nombre":      ["Ana", "Luis", "Eva", "Carlos", "Marta", "Pedro", "Laura", "Tomás"],
    "departamento":["IT", "Ventas", "IT", "RRHH", "Ventas", "IT", "RRHH", "Ventas"],
    "edad":        [23, 31, 28, None, 22, 38, 35, 27],
    "salario":     [28000, 42000, 35000, None, 24000, 55000, 48000, 31000],
    "activo":      [True, True, False, True, True, True, False, True],
    "fecha_alta":  pd.to_datetime(["2022-01-10", "2019-06-15", "2021-03-20",
                                   "2015-11-01", "2023-02-28", "2017-08-12",
                                   "2020-04-05", "2021-09-18"])
})

print(df)
print(df.describe())
# Out:
#    nombre departamento  edad  salario  activo fecha_alta
# 0     Ana           IT  23.0  28000.0    True 2022-01-10
# 1    Luis       Ventas  31.0  42000.0    True 2019-06-15
# 2     Eva           IT  28.0  35000.0   False 2021-03-20
# 3  Carlos         RRHH   NaN      NaN    True 2015-11-01
# 4   Marta       Ventas  22.0  24000.0    True 2023-02-28
# 5   Pedro           IT  38.0  55000.0    True 2017-08-12
# 6   Laura         RRHH  35.0  48000.0   False 2020-04-05
# 7   Tomás       Ventas  27.0  31000.0    True 2021-09-18
#             edad       salario           fecha_alta
# count   7.000000      7.000000                    8
# mean   29.142857  37571.428571  2020-02-28 03:00:00
# min    22.000000  24000.000000  2015-11-01 00:00:00
# 25%    25.000000  29500.000000  2018-12-29 00:00:00
# 50%    28.000000  35000.000000  2020-09-26 12:00:00
# 75%    33.000000  45000.000000  2021-10-16 12:00:00
# max    38.000000  55000.000000  2023-02-28 00:00:00
# std     5.928141  11237.691680                  NaN

# %% [markdown]
# ## Exploracion de columnas por categoria: value_counts, unique, nunique

# %%
## value_counts: repeticion de cada valor, IT
print(df['departamento'].value_counts())

print(df['departamento'].value_counts(normalize=True) * 100)
# Out:
# departamento
# IT        3
# Ventas    3
# RRHH      2
# Name: count, dtype: int64
# departamento
# IT        37.5
# Ventas    37.5
# RRHH      25.0
# Name: proportion, dtype: float64

# %% [markdown]
# ## Valores nulos: primera deteccion

# %%
print(df.isnull())
print('total de nulos')
print(df.isnull().sum())
# Out:
#    nombre  departamento   edad  salario  activo  fecha_alta
# 0   False         False  False    False   False       False
# 1   False         False  False    False   False       False
# 2   False         False  False    False   False       False
# 3   False         False   True     True   False       False
# 4   False         False  False    False   False       False
# 5   False         False  False    False   False       False
# 6   False         False  False    False   False       False
# 7   False         False  False    False   False       False
# total de nulos
# nombre          0
# departamento    0
# edad            1
# salario         1
# activo          0
# fecha_alta      0
# dtype: int64

# %%
# lista de valores unicos por departamento

print( df['departamento'].unique())

#nunique : numero de valores unicos por columna

print(df.nunique())
# Out:
# <StringArray>
# ['IT', 'Ventas', 'RRHH']
# Length: 3, dtype: str
# nombre          8
# departamento    3
# edad            7
# salario         7
# activo          2
# fecha_alta      8
# dtype: int64
