# %%
import pandas as pd


print(pd.DataFrame([1,2,3,4,5]))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2
#       3
#       4 print(pd.DataFrame([1,2,3,4,5]))
#
# File c:\big_data\python\clases_python_bigdata\7_pandas_numpy\manipular_pandas\.venv\Lib\site-packages\pandas\__init__.py:46
#      38     _module = _err.name
#      39     raise ImportError(
#      40         f"C extension: {_module} not built. If you want to import "
#      41         "pandas from the source directory, you may need to run "
#      42         "'python -m pip install -ve . --no-build-isolation -Ceditable-verbose=true' "
#      43         "to build the C extensions first."
#      44     ) from _err
# ---> 46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#      49     reset_option,
#      50     describe_option,
#      51     option_context,
#      52     options,
# ...
